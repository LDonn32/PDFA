# %% [markdown]
# # AI & MI

# %% [markdown]
# __Artificual Intelligence and Machine Learning__

# %% [markdown]
# - Computers are historically very good at following instructions, you tell a computer program what to do and it will do it step by step.
#
# - Humans are really good at pattern regocnition.
#
# - AI meant whatever computers could not do well. It is a term that gets misued often, even by computer scientists. It was used for Sound, Vission, Complex problem sets, chess.
#
# - Machine Leanring is taking past data to predict future data. Long Large Language models (LLMs) take a lot of past data, things that are written to try and predict the next word.

# %% [markdown]
# _Decisions Trees_
#
# Example of this would be noughts and crosses. What moves can they make after mine.
#
# But they can get complicated quickly.
#
# Good for small data sets.
#
# For chess it is very difficult as they are too many types of games that can be played.
#
# AI has moved a bit away from decions trees.

# %% [markdown]
# ## Machine Learning
#
# Modern Machine Learning is a lot more statistical.
#
# Splitting data into training data and testing data is vital to ML
#
# ## Types of algorthms ##
#
# __Supervised:__
#
# _e.g. the Iris dataset_
#
# The dataset is labelled
#
# Some results are given
#
# - Linear Regression
#
# - Logistic Regression
#
# - SVM
#
# - KNN
#
# __Unsupervised:__
#
# The dataset is unlabelled.
#
# Results are not pre known but information can be extracted from the data.
#
# Discover patterns.
#
# - K-Means
#
# - C-Means
#
# - Apriori
#
# __Reinforcement:__
#
# Reward given for wanted behaviour.
#
# - Q - Learning
#
# - SARSA

# %% [markdown]
# # Libraries for Python
#
# - __Scikit-learn__
#
#     - Open source, built on top of NumPy and matplotlib
#
#     - Simple to use
#
#     - BSD licence so you can sell applications that use it
#
# - __Tensorflow__
#
#     - Google, open source
#
#     - Very powerful
#
#     - Used in nueral networks
#
#     - Keras, Tensorflow-probability are build on top of it
#
# - __Pytorch__
#
#     - Facebook
#
#     - A rule of thumb is that PyTorch is better at research-orientated projects and Tensorflow is a better fit for prodfuction use.

# %% [markdown]
# Issues
#
# - Over training your data
#
# - How do you know it is any good
#
# - train_test_split
#
# - Normalising the inputs
